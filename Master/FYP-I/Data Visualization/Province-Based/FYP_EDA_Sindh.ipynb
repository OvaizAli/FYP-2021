# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
all_prov_df = pd.read_csv("/content/drive/MyDrive/fixed_data/all_province.csv")

# %%
all_prov_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  S.No  ... Barometer Visibility Weather
# 0           0             0     1  ...     31.43       0.00   Haze.
# 1           0             0     3  ...      0.00       0.00  Sunny.
# 2           0             0     5  ...     56.79      23.12  Clear.
# 3           0             0     6  ...      0.00       0.00  Sunny.
# 4           0             0     4  ...     49.20      23.21    Fog.
#
# [5 rows x 48 columns]

# %% [markdown]
# # Data Cleaning (W.R.T this notebook)

# %%
columns = ["Confirmed", "Daily_Confirmed", "Deaths", "Daily_Deaths", "inf_mean", "inf_upper", "inf_lower", "seir_cumulative_mean", "seir_cumulative_lower", "seir_cumulative_upper", "inf_cuml_mean", "inf_cuml_lower", "inf_cuml_upper", "seir_daily_mean", "seir_daily_lower", "seir_daily_upper", "population", "mobility_mean", "mobility_obs", "testing_obs", "pneumonia_mean", "pneumonia_obs", "mask_use_mean", "mask_use_obs", "hospital_beds_mean", "hospital_beds_upper", "hospital_beds_lower", "icu_beds_mean", "icu_beds_upper", "icu_beds_lower", "all_bed_capacity", "icu_bed_capacity", "Temp", "Wind", "Barometer", "Visibility"]

for i in range(len(all_prov_df)):
  for j in columns:
    if all_prov_df[j][i] < 0:
      all_prov_df[j][i] = abs(all_prov_df[j][i])

# %% [markdown]
# # Data Visualization

# %%
month = { 1 : "JAN", 2 : "FEB", 3 : "MAR", 4 : "APR", 5 : "MAY", 6 : "JUN", 7 : "JUL", 8 : "AUG", 9 : "SEP", 10 : "OCT", 11 : "NOV", 12: "DEC"}

# %% [markdown]
# # Part 1 (Individual Feature Analysis)

# %% [markdown]
# ## Daily Confirmed Cases (Monthly for year 2020)

# %%
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6)) 
    x = list(sindh_df_month["Daily_Confirmed"])
    z = list(sindh_df_month["Day"])
    plt.plot(z, x)
    plt.xlabel('Day No.')
    plt.ylabel('Number of Confirmed Cases')
    plt.title(f"DAILY CONFIRMED CASES IN {month[i]} 2020 [SINDH]")
    plt.show()

# %% [markdown]
# ## Daily Deaths (Monthly for year 2020)

# %%
count = 0
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6)) 
    x = list(sindh_df_month["Daily_Deaths"])
    z = list(sindh_df_month["Day"])
    plt.plot(z, x)
    plt.xlabel('Day No.')
    plt.ylabel('Number of Deaths')
    plt.title(f"DAILY DEATHS IN IN {month[i]} 2020 [SINDH]")
    plt.show()

# %% [markdown]
# ## Daily Confirmed Cases (Monthly for year 2021)

# %%
count = 0
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6)) 
    x = list(sindh_df_month["Daily_Confirmed"])
    z = list(sindh_df_month["Day"])
    plt.plot(z, x)
    plt.xlabel('Day No.')
    plt.ylabel('Number of Confirmed Cases')
    plt.title(f"DAILY CONFIRMED CASES IN {month[i]} 2021 [SINDH]")
    plt.show()

# %% [markdown]
# ## Daily Deaths (Monthly for year 2021)

# %%
count = 0
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6)) 
    x = list(sindh_df_month["Daily_Deaths"])
    z = list(sindh_df_month["Day"])
    plt.plot(z, x)
    plt.xlabel('Day No.')
    plt.ylabel('Number of Deaths')
    plt.title(f"DAILY DEATHS IN {month[i]} 2020 [SINDH]")
    plt.show()

# %% [markdown]
# ## Maximum Confirmed Cases Recorded Monthly in 2020

# %%
x = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6)) 
    x.append(sindh_df_month["Daily_Confirmed"].max())
    z.append(month[i])
    plt.plot(z, x)
    plt.xlabel('Month')
    plt.ylabel('Number of Confirmed Cases')

plt.title(f"MAXIMUM CONFIRMED CASES RECORDED MONTHLY IN 2020 [SINDH]")
plt.show()

# %% [markdown]
# ## Maximum Daily Deaths Recorded Monthly in 2020

# %%
count = 0
x = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6)) 
    x.append(sindh_df_month["Daily_Deaths"].max())
    z.append(month[i])
    plt.plot(z, x)
    plt.xlabel('Month')
    plt.ylabel('Number of Daily Deaths')

plt.title(f"MAXIMUM DAILY DEATHS RECORDED MONTHLY IN 2020 [SINDH]")
plt.show()

# %% [markdown]
# ## Maximum Confirmed Cases Recorded Monthly in 2021

# %%
x = []
z = []
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6)) 
    x.append(sindh_df_month["Daily_Confirmed"].max())
    z.append(month[i])
    plt.plot(z, x)
    plt.xlabel('Month')
    plt.ylabel('Number of Confirmed Cases')

plt.title(f"MAXIMUM CONFIRMED CASES RECORDED MONTHLY IN 2021 [SINDH]")
plt.show()

# %% [markdown]
# ## Maximum Daily Deaths Recorded Monthly in 2021

# %%
x = []
z = []
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6)) 
    x.append(sindh_df_month["Daily_Deaths"].max())
    z.append(month[i])
    plt.plot(z, x)
    plt.xlabel('Month')
    plt.ylabel('Number of Daily Deaths')

plt.title(f"MAXIMUM DAILY DEATHS RECORDED MONTHLY IN 2021 [SINDH]")
plt.show()

# %% [markdown]
# ### Monthly Hospital Beds Usage and ICU Beds Usage in 2020

# %%
count = 0
x = []
y = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6)) 
    x.append(sindh_df_month["hospital_beds_upper"].max())
    y.append(sindh_df_month["icu_beds_upper"].max())
    z.append(month[i])
plt.plot(z, x, label = "Hospital Beds Usage")
plt.plot(z, y, label = "ICU Beds Usage")
plt.xlabel('Month')
plt.title(f"MONTHLY HOSPITAL BEDS USAGE VS ICU BEDS USAGE IN 2020 [SINDH]")
plt.legend()
plt.show()

# %% [markdown]
# ### Monthly Hospital Beds Usage and ICU Beds Usage in 2021

# %%
count = 0
x = []
y = []
z = []
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6)) 
    x.append(sindh_df_month["hospital_beds_upper"].max())
    y.append(sindh_df_month["icu_beds_upper"].max())
    z.append(month[i])
plt.plot(z, x, label = "Hospital Beds Usage")
plt.plot(z, y, label = "ICU Beds Usage")
plt.xlabel('Month')
plt.title(f"MONTHLY HOSPITAL BEDS USAGE VS ICU BEDS USAGE IN 2021 [SINDH]")
plt.legend()
plt.show()

# %% [markdown]
# ## Monthly Mask Usage in 2020

# %%
count = 0
x = []
y = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6))
    y.append(sindh_df_month["mask_use_mean"].max()*100)
    z.append(month[i])
plt.plot(z, y, label = "Mask Usage")
plt.xlabel('Month')
plt.ylabel('Mask Use (%)')
plt.title(f"MONTHLY MASK USAGE IN 2020 [SINDH]")
plt.legend()
plt.show()

# %% [markdown]
# ## Monthly Mask Usage in 2021

# %%
count = 0
x = []
y = []
z = []
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6))
    y.append(sindh_df_month["mask_use_mean"].max()*100)
    z.append(month[i])
plt.plot(z, y, label = "Mask Usage")
plt.xlabel('Month')
plt.ylabel('Mask Use (%)')
plt.title(f"MONTHLY MASK USAGE IN 2021 [SINDH]")
plt.legend()
plt.show()

# %% [markdown]
# ## Monthly Change in Mobility in 2020

# %%
count = 0
x = []
y = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6))
    y.append(sindh_df_month["mobility_mean"].max())
    z.append(month[i])
plt.plot(z, y, label = "Change in Mobility")
plt.xlabel('Month')
plt.ylabel('Change in Mobility (%)')
plt.title(f"MONTHLY CHANGE IN MOBILITY IN 2020 [SINDH]")
plt.legend()
plt.show()

# %% [markdown]
# ## Monthly Change in Mobility in 2021

# %%
count = 0
x = []
y = []
z = []
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6))
    y.append(sindh_df_month["mobility_mean"].max())
    z.append(month[i])
plt.plot(z, y, label = "Change in Mobility")
plt.xlabel('Month')
plt.ylabel('Change in Mobility (%)')
plt.title(f"MONTHLY CHANGE IN MOBILITY IN 2021 [SINDH]")
plt.legend()
plt.show()

# %% [markdown]
# ## Monthly Mean Temperature in 2020

# %%
count = 0
x = []
y = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6))
    y.append(sindh_df_month["Temp"].mean())
    z.append(month[i])
plt.xlabel('Month')
plt.ylabel('Mean Temperature (F)')
plt.plot(z, y, label = "Mean Temperature")
plt.title(f"MONTHLY MEAN TEMPERATURE IN 2020 [SINDH]")
plt.legend()
plt.show()

# %% [markdown]
# ## Monthly Mean Temperature in 2021

# %%
count = 0
x = []
y = []
z = []
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6))
    y.append(sindh_df_month["Temp"].mean())
    z.append(month[i])
plt.xlabel('Month')
plt.ylabel('Mean Temperature (F)')
plt.plot(z, y, label = "Mean Temperature")
plt.title(f"MONTHLY MEAN TEMPERATURE IN 2021 [SINDH]")
plt.legend()
plt.show()

# %% [markdown]
# ## Monthly Mean Wind Speed in 2020

# %%
count = 0
x = []
y = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6))
    y.append(sindh_df_month["Wind"].mean())
    z.append(month[i])
plt.xlabel('Month')
plt.ylabel('Mean Wind Speed (km/h)')
plt.plot(z, y, label = "Mean Wind Speed")
plt.title(f"MONTHLY MEAN WIND SPEED IN 2020 [SINDH]")
plt.legend()
plt.show()

# %% [markdown]
# ## Monthly Wind Speed Statistics in 2021

# %%
count = 0
x = []
y = []
z = []
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6))
    y.append(sindh_df_month["Wind"].mean())
    z.append(month[i])
plt.xlabel('Month')
plt.ylabel('Mean Wind Speed (km/h)')
plt.plot(z, y, label = "Mean Wind Speed")
plt.title(f"MONTHLY MEAN WIND SPEED IN 2021 [SINDH]")
plt.legend()
plt.show()

# %% [markdown]
# ## Monthly Barometer Statistics in 2020

# %%
count = 0
x = []
y = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6))
    y.append(sindh_df_month["Barometer"].mean())
    z.append(month[i])
plt.xlabel('Month')
plt.ylabel('Mean Barometer (mbar)')
plt.plot(z, y, label = "Mean Barometer")
plt.title(f"MONTHLY MEAN BAROMETER STATISTICS IN 2020 [SINDH]")
plt.legend()
plt.show()

# %% [markdown]
# ## Monthly Barometer Statistics in 2021

# %%
count = 0
x = []
y = []
z = []
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6))
    y.append(sindh_df_month["Barometer"].mean())
    z.append(month[i])
plt.xlabel('Month')
plt.ylabel('Mean Barometer (mbar)')
plt.plot(z, y, label = "Mean Barometer")
plt.title(f"MONTHLY MEAN BAROMETER STATISTICS IN 2021 [SINDH]")
plt.legend()
plt.show()

# %% [markdown]
# ## Monthly Visibility Statistics in 2020

# %%
count = 0
x = []
y = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6))
    y.append(sindh_df_month["Visibility"].mean())
    z.append(month[i])
plt.xlabel('Month')
plt.ylabel('Mean Visibility (km)')
plt.plot(z, y, label = "Mean Visibility")
plt.title(f"MONTHLY MEAN VISIBILITY STATISTICS IN 2020 [SINDH]")
plt.legend()
plt.show()

# %% [markdown]
# ## Monthly Visibility Statistics in 2021

# %%
count = 0
x = []
y = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    fig = plt.figure(figsize = (10,6))
    y.append(sindh_df_month["Visibility"].mean())
    z.append(month[i])
plt.xlabel('Month')
plt.ylabel('Mean Visibility (km)')
plt.plot(z, y, label = "Mean Visibility")
plt.title(f"MONTHLY MEAN VISIBILITY STATISTICS IN 2020 [SINDH]")
plt.legend()
plt.show()

# %% [markdown]
# # Part 2 (Comparative Analysis Between Different Features)

# %%
sindh_df2020 = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Year'] == 2020)]
sindh_df2020.drop("Unnamed: 0", axis = 1, inplace = True)

sindh_df2021 = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Year'] == 2021)]
sindh_df2021.drop("Unnamed: 0", axis = 1, inplace = True)

# %% [markdown]
# ## Comparision of Maximum Confirmed Cases and Maximum Daily Deaths [Monthly in 2020]

# %%
count = 0
x = []
y = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    x.append(sindh_df_month["Daily_Confirmed"].max())
    y.append(sindh_df_month["Daily_Deaths"].max())
    z.append(month[i])
fig, ax1 = plt.subplots(figsize = (10,6))

color = 'tab:red'
ax1.set_xlabel('Month')
ax1.set_ylabel('Max Confirmed Cases', color=color)
ax1.plot(z, x, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Max Daily Deaths', color=color)  
ax2.plot(z, y, color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title(f"MONTHLY MAXIMUM CONFIRMED CASES VS MAXIMUM DAILY DEATHS IN 2020 [SINDH]")
fig.tight_layout()  
plt.show()

# %% [markdown]
# ## Comparision of Maximum Confirmed Cases and Maximum Daily Deaths [Monthly in 2021]

# %%
count = 0
x = []
y = []
z = []
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    x.append(sindh_df_month["Daily_Confirmed"].max())
    y.append(sindh_df_month["Daily_Deaths"].max())
    z.append(month[i])
fig, ax1 = plt.subplots(figsize = (10,6))

color = 'tab:red'
ax1.set_xlabel('Month')
ax1.set_ylabel('Max Confirmed Cases', color=color)
ax1.plot(z, x, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Max Daily Deaths', color=color)  
ax2.plot(z, y, color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title(f"MONTHLY MAXIMUM CONFIRMED CASES VS MAXIMUM DAILY DEATHS IN 2021 [SINDH]")
fig.tight_layout()  
plt.show()

# %% [markdown]
# ## Comparision of Monthly Mean Infections and Mean Daily Deaths in 2020

# %%
count = 0
x = []
y = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    x.append(sindh_df_month["inf_mean"].mean())
    y.append(sindh_df_month["Daily_Deaths"].mean())
    z.append(month[i])
fig, ax1 = plt.subplots(figsize = (10,6))

color = 'tab:red'
ax1.set_xlabel('Month')
ax1.set_ylabel('Infection Mean', color=color)
ax1.plot(z, x, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Daily Deaths', color=color)  
ax2.plot(z, y, color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title(f"MONTHLY MEAN INFECTIONS VS MEAN DAILY DEATHS IN 2020 [SINDH]")
fig.tight_layout()  
plt.show()

# %% [markdown]
# ## Comparision of Monthly Mean Infections and Mean Daily Deaths in 2021

# %%
count = 0
x = []
y = []
z = []
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    x.append(sindh_df_month["inf_mean"].mean())
    y.append(sindh_df_month["Daily_Deaths"].mean())
    z.append(month[i])
fig, ax1 = plt.subplots(figsize = (10,6))

color = 'tab:red'
ax1.set_xlabel('Month')
ax1.set_ylabel('Infection Mean', color=color)
ax1.plot(z, x, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Daily Deaths', color=color)  
ax2.plot(z, y, color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title(f"MONTHLY MEAN INFECTIONS VS MEAN DAILY DEATHS IN 2021 [SINDH]")
fig.tight_layout()  
plt.show()

# %% [markdown]
# ## Comparision of Mean Confirmed Cases and Mean Temperature [Monthly in 2020]

# %%
count = 0
x = []
y = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    x.append(sindh_df_month["Daily_Confirmed"].mean())
    y.append(sindh_df_month["Temp"].mean())
    z.append(month[i])
fig, ax1 = plt.subplots(figsize = (10,6))

color = 'tab:red'
ax1.set_xlabel('Month')
ax1.set_ylabel('Mean Confirmed Cases', color=color)
ax1.plot(z, x, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Mean Temperature (F)', color=color)  
ax2.plot(z, y, color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title(f"MONTHLY MEAN CONFIRMED CASES VS MEAN TEMPERATURE IN 2020 [SINDH]")
fig.tight_layout()  
plt.show()

# %% [markdown]
# ## Comparision of Mean Daily Confirmed Cases and Mean Temperature [Monthly in 2021]

# %%
count = 0
x = []
y = []
z = []
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    x.append(sindh_df_month["Daily_Confirmed"].mean())
    y.append(sindh_df_month["Temp"].mean())
    z.append(month[i])
fig, ax1 = plt.subplots(figsize = (10,6))

color = 'tab:red'
ax1.set_xlabel('Month')
ax1.set_ylabel('Mean Confirmed Cases', color=color)
ax1.plot(z, x, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Mean Temperature (F)', color=color)  
ax2.plot(z, y, color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title(f"MONTHLY MEAN CONFIRMED CASES VS MEAN TEMPERATURE IN 2021 [SINDH]")
fig.tight_layout()  
plt.show()

# %% [markdown]
# ## Comparision of Mean Daily Confirmed Cases and Mean Wind Speed [Monthly in 2020]

# %%
count = 0
x = []
y = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    x.append(sindh_df_month["Daily_Confirmed"].mean())
    y.append(sindh_df_month["Wind"].mean())
    z.append(month[i])
fig, ax1 = plt.subplots(figsize = (10,6))

color = 'tab:red'
ax1.set_xlabel('Month')
ax1.set_ylabel('Mean Confirmed Cases', color=color)
ax1.plot(z, x, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Mean Wind Speed (km/h)', color=color)  
ax2.plot(z, y, color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title(f"MONTHLY MEAN CONFIRMED CASES VS MEAN WIND SPEED IN 2020 [SINDH]")
fig.tight_layout()  
plt.show()

# %% [markdown]
# ## Comparision of Mean Daily Confirmed Cases and Mean Wind Speed [Monthly in 2021]

# %%
count = 0
x = []
y = []
z = []
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    x.append(sindh_df_month["Daily_Confirmed"].mean())
    y.append(sindh_df_month["Wind"].mean())
    z.append(month[i])
fig, ax1 = plt.subplots(figsize = (10,6))

color = 'tab:red'
ax1.set_xlabel('Month')
ax1.set_ylabel('Mean Confirmed Cases', color=color)
ax1.plot(z, x, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Mean Wind Speed (km/h)', color=color)  
ax2.plot(z, y, color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title(f"MONTHLY MEAN CONFIRMED CASES VS MEAN WIND SPEED IN 2021 [SINDH]")
fig.tight_layout()  
plt.show()

# %% [markdown]
# ## Comparision of Mean Daily Confirmed Cases and Mean Barometer Statistics [Monthly in 2020]

# %%
count = 0
x = []
y = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    x.append(sindh_df_month["Daily_Confirmed"].mean())
    y.append(sindh_df_month["Barometer"].mean())
    z.append(month[i])
fig, ax1 = plt.subplots(figsize = (10,6))

color = 'tab:red'
ax1.set_xlabel('Month')
ax1.set_ylabel('Mean Confirmed Cases', color=color)
ax1.plot(z, x, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Mean Barometer (mbar)', color=color)  
ax2.plot(z, y, color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title(f"MONTHLY MEAN CONFIRMED CASES VS MEAN BAROMETER STATISTICS IN 2020 [SINDH]")
fig.tight_layout()  
plt.show()

# %% [markdown]
# ## Comparision of Mean Daily Confirmed Cases and Mean Barometer Statistics [Monthly in 2021]

# %%
count = 0
x = []
y = []
z = []
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    x.append(sindh_df_month["Daily_Confirmed"].mean())
    y.append(sindh_df_month["Barometer"].mean())
    z.append(month[i])
fig, ax1 = plt.subplots(figsize = (10,6))

color = 'tab:red'
ax1.set_xlabel('Month')
ax1.set_ylabel('Mean Confirmed Cases', color=color)
ax1.plot(z, x, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Mean Barometer (mbar)', color=color)  
ax2.plot(z, y, color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title(f"MONTHLY MEAN CONFIRMED CASES VS MEAN BAROMETER STATISTICS IN 2021 [SINDH]")
fig.tight_layout()  
plt.show()

# %% [markdown]
# ## Comparision of Mean Daily Confirmed Cases and Mean Visibility Statistics [Monthly in 2020]

# %%
count = 0
x = []
y = []
z = []
for i in range(3,13):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2020)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    x.append(sindh_df_month["Daily_Confirmed"].mean())
    y.append(sindh_df_month["Visibility"].mean())
    z.append(month[i])
fig, ax1 = plt.subplots(figsize = (10,6))

color = 'tab:red'
ax1.set_xlabel('Month')
ax1.set_ylabel('Mean Confirmed Cases', color=color)
ax1.plot(z, x, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Mean Visibility (km)', color=color)  
ax2.plot(z, y, color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title(f"MONTHLY MEAN CONFIRMED CASES VS MEAN VISIBILITY STATISTICS IN 2020 [SINDH]")
fig.tight_layout()  
plt.show()

# %% [markdown]
# ## Comparision of Mean Daily Confirmed Cases and Mean Visibility Statistics [Monthly in 2021]

# %%
count = 0
x = []
y = []
z = []
for i in range(1,11):
    sindh_df_month = all_prov_df.loc[(all_prov_df['Province'] == "Sindh") & (all_prov_df['Month'] == i) 
                                     & (all_prov_df['Year'] == 2021)]
    sindh_df_month.drop("Unnamed: 0", axis = 1,inplace = True)


    # %matplotlib inline

    # Create the plot
    x.append(sindh_df_month["Daily_Confirmed"].mean())
    y.append(sindh_df_month["Visibility"].mean())
    z.append(month[i])
fig, ax1 = plt.subplots(figsize = (10,6))

color = 'tab:red'
ax1.set_xlabel('Month')
ax1.set_ylabel('Mean Confirmed Cases', color=color)
ax1.plot(z, x, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  

color = 'tab:blue'
ax2.set_ylabel('Mean Visibility (km)', color=color)  
ax2.plot(z, y, color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title(f"MONTHLY MEAN CONFIRMED CASES VS MEAN VISIBILITY STATISTICS IN 2021 [SINDH]")
fig.tight_layout()  
plt.show()
